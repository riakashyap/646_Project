# %%
# EXPORT-IGNORE-START

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
# !pip install datasets==3.6.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets==3.6.0 in /home/bdunahu/.local/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: filelock in /home/bdunahu/.guix-home/profile/lib/python3.11/site-packages (from datasets==3.6.0) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /gnu/store/xx35gmhrpy8axgd2kq6v7dc2bq61ji2z-python-numpy-1.26.4/lib/python3.11/site-packages (from datasets==3.6.0) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from datasets==3.6.0) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from datasets==3.6.0) (0.3.8)
# Requirement already satisfied: pandas in /home/bdunahu/.local/lib/python3.11/site-packages (from datasets==3.6.0) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /home/bdunahu/.local/lib/python3.11/site-packages (from datasets==3.6.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /home/bdunahu/.guix-home/profile/lib/python3.11/site-packages (from datasets==3.6.0) (4.67.1)
# Requirement already satisfied: xxhash in /home/bdunahu/.local/lib/python3.11/site-packages (from datasets==3.6.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/bdunahu/.local/lib/python3.11/site-packages (from datasets==3.6.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from datasets==3.6.0) (0.35.0)
# Requirement already satisfied: packaging in /gnu/store/qigmcba93sv01an638f503lpw4k58lkj-python-packaging-25.0/lib/python3.11/site-packages (from datasets==3.6.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /gnu/store/s6y6qdgxg8ynprc37hd3cfi71g2qscbx-python-pyyaml-6.0.2/lib/python3.11/site-packages (from datasets==3.6.0) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/bdunahu/.local/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /gnu/store/fab2q5k5f4ypqd8mvr3f8fwmp2jq1zqf-python-attrs-25.3.0/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/bdunahu/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/bdunahu/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/bdunahu/.local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /gnu/store/ijpn1q7mjf7h7mzds2jms71hs81h6n6i-python-idna-3.10/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.10)
# Requirement already satisfied: typing-extensions>=4.2 in /home/bdunahu/.local/lib/python3.11/site-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/bdunahu/.local/lib/python3.11/site-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /gnu/store/qr3hq9nlhhxp586g2invlcy7a51jhlnv-python-charset-normalizer-3.4.2/lib/python3.11/site-packages (from requests>=2.32.2->datasets==3.6.0) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /gnu/store/dvhv24r4ima94qnrpcahgpr11kd753l0-python-urllib3-2.5.0/lib/python3.11/site-packages (from requests>=2.32.2->datasets==3.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /gnu/store/08lc2z893p8c4dknhd8nj184nh8r3aw9-python-certifi-2025.06.15/lib/python3.11/site-packages (from requests>=2.32.2->datasets==3.6.0) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /gnu/store/lagnwa1k45jlk64dc55bj9p6blr9g274-python-dateutil-2.9.0/lib/python3.11/site-packages (from pandas->datasets==3.6.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/bdunahu/.local/lib/python3.11/site-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/bdunahu/.local/lib/python3.11/site-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /gnu/store/p2mixjf96p4d4j7hqmwjvpj0gvhr66w8-python-six-1.17.0/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0) (1.17.0)

# %%
# EXPORT-IGNORE-END

# %%
def in_jupyter_notebook():
    try:
        shell = get_ipython().__class__.__name__
        return shell == 'ZMQInteractiveShell'
    except NameError:
        return False
IN_JUPYTER = in_jupyter_notebook()

# %%
if IN_JUPYTER:
    from src import LLMClient
else:
    import LLMClient

from typing import Dict
from datasets import load_dataset
from tqdm import tqdm
from collections import Counter
import time
import textwrap
import json
import numpy as np

# %% [markdown]
# Create the client objects:

# %%
# we need this temporarily to test the pipeline without RAG
LLMClient.PromptAnalyzer._prompts["answer_question"] = ("Tersely answer this question to the best of your ability. Never ask for more context. Assume you know the answer.", "Question: {}\nAnswer: ")

prompts = [
    "initial_question",
    "follow_up",
    "secondary_question",
    "final_verdict",
    "answer_question"
]

ILC, FLC, SLC, VLC, ALC = [
    LLMClient.LlamaCppClient(LLMClient.PromptAnalyzer.get_system_message(p)) for p in prompts
]

# %% [markdown]
# ## Verify Claim

# %%
def verify_claim(claim: str, max_iters: int = 3) -> str | None:

  # Generate initial question
  initial_prompt = LLMClient.PromptAnalyzer.build_template("initial_question", [claim])
  question = ILC.send_query(initial_prompt).strip()

  qa_pairs = []
  for _ in range(max_iters):
    # Answer question (real pipeline should use RAG here)
    answer_prompt = LLMClient.PromptAnalyzer.build_template("answer_question", [question])
    answer = ALC.send_query(answer_prompt).strip()
    qa_pairs.append((question, answer))

    # Check for termination
    check_prompt = LLMClient.PromptAnalyzer.build_template("follow_up", [claim, qa_pairs])
    check_response = FLC.send_query(check_prompt)
    done = LLMClient.PromptAnalyzer.parse_conclusivity(check_response)
    if done or done == None:  
      break

    # Generate follow-up
    secondary_prompt = LLMClient.PromptAnalyzer.build_template("secondary_question", [claim, qa_pairs])
    question = SLC.send_query(secondary_prompt).strip()

  # Final verification
  verify_prompt = LLMClient.PromptAnalyzer.build_prompt("final_verdict", [claim, qa_pairs])
  verdict_raw = VLC.send_query(verify_prompt).strip()
  verdict_bool = LLMClient.PromptAnalyzer.parse_boolean_answer(verdict_raw)

  result = {
    "claim": claim,
    "qa_pairs": qa_pairs,
    "verdict_raw": verdict_raw,
    "verdict_bool": verdict_bool,
  }

  return result

# %% [markdown]
# ## Tests

# %%
# EXPORT-IGNORE-START

# %% [markdown]
# Tests completed using the `Qwen3-1.7B-Q8_0.gguf` model.

# %%
def is_correct(expected, actual):
    if actual is None:
        pred = "not enough info"
    if actual:
        pred = "supports"
    else:
        pred = "refutes"

    return pred == expected

# %%
ds = load_dataset("fever", "v1.0", trust_remote_code=True)

# %%
num_samples = 10
split = ds["labelled_dev"].select(range(num_samples))
results = []

for i in tqdm(range(len(split))):
    claim = split[i]["claim"]
    label = split[i]["label"].lower()

    result = verify_claim(claim)
    result["correct"] = is_correct(label, result["verdict_bool"])
    
    results.append(result)
# Out:
# 100%|█████████████████████████████████████████████████████████| 10/10 [11:51<00:00, 71.19s/it]

# %%
import pprint
pprint.pprint(results)
# Out:
# [{'claim': 'Colin Kaepernick became a starting quarterback during the 49ers '
#            '63rd season in the National Football League.',
#   'correct': False,
#   'qa_pairs': [("Who became a starting quarterback during the 49ers' 63rd "
#                 'season in the National Football League?',
#                 "Step 1: Identify the 49ers' 63rd season.\n"
#                 "The 49ers' 63rd season was in 2016.\n"
#                 '\n'
#                 'Step 2: Determine the quarterback during the 63rd season.\n'
#                 'The starting quarterback for the 49ers in 2016 was Colin '
#                 'Kaepernick.\n'
#                 '\n'
#                 'Answer: Colin Kaepernick')],
#   'verdict_bool': True,
#   'verdict_raw': 'True'},
#  {'claim': 'Tilda Swinton is a vegan.',
#   'correct': False,
#   'qa_pairs': [('Is Tilda Swinton a vegan?',
#                 'No, Tilda Swinton is not a vegan.')],
#   'verdict_bool': False,
#   'verdict_raw': 'False'},
#  {'claim': 'Fox 2000 Pictures released the film Soul Food.',
#   'correct': False,
#   'qa_pairs': [('Who released the film Soul Food?',
#                 'Rampage Films released the film Soul Food.'),
#                ('When did Fox 2000 Pictures release the film Soul Food?',
#                 '2012'),
#                ('What is the release year of the film Soul Food?', '2019')],
#   'verdict_bool': None,
#   'verdict_raw': 'In a single, concise, logical sentence, address if the '
#                  'question-evidence pairs fully confirm or disprove the '
#                  'claim.\n'
#                  '\n'
#                  'True\n'
#                  '\n'
#                  'Conclude with "True" or "False" depending on the '
#                  'truthfulness of the claim, otherwise respond with '
#                  '"Inconclusive" if the evidence is inconclusive. No other '
#                  'output is needed or warranted.'},
#  {'claim': 'Fox 2000 Pictures released the film Soul Food.',
#   'correct': False,
#   'qa_pairs': [('Who released the film Soul Food?',
#                 "I'm sorry, but I don't have enough information to determine "
#                 'who released the film "Soul Food". This question seems to be '
#                 'missing crucial details. Could you please provide more '
#                 'context or clarify the question?'),
#                ('Who released the film Soul Food?', 'Ruth Negga'),
#                ('Who released the film Soul Food?', 'Warner Bros.')],
#   'verdict_bool': None,
#   'verdict_raw': 'Inconclusive\n'
#                  '\n'
#                  'Explanation: The question-answers do not provide enough '
#                  'specific details to confirm or disprove the claim that Fox '
#                  '2000 Pictures released the film Soul Food. More context or '
#                  'information is needed to determine the truthfulness of the '
#                  'claim.'},
#  {'claim': 'Fox 2000 Pictures released the film Soul Food.',
#   'correct': False,
#   'qa_pairs': [('Who released the film Soul Food?',
#                 'A: The film Soul Food was released in 2020 by Netflix.')],
#   'verdict_bool': False,
#   'verdict_raw': 'In a single, concise, logical sentence, address if the '
#                  'question-evidence pairs fully confirm or disprove the claim: '
#                  '"Fox 2000 Pictures released the film Soul Food."\n'
#                  '\n'
#                  'The evidence suggests that the film "Soul Food" was released '
#                  'in 2020 by Netflix, not Fox 2000 Pictures. Therefore, the '
#                  'claim is disproven.\n'
#                  '\n'
#                  '**Conclusion:** False\n'
#                  '\n'
#                  '**Inconclusive**'},
#  {'claim': 'Fox 2000 Pictures released the film Soul Food.',
#   'correct': False,
#   'qa_pairs': [('Who released the film Soul Food?', 'Ruth St. Barbe'),
#                ('When was the film Soul Food released?', '2021'),
#                ('What specific film did Fox 2000 Pictures release in 2021?',
#                 '"Black Widow"')],
#   'verdict_bool': False,
#   'verdict_raw': 'False'},
#  {'claim': 'Fox 2000 Pictures released the film Soul Food.',
#   'correct': False,
#   'qa_pairs': [('Who released the film Soul Food?', 'Tupac Shakur'),
#                ('When was the film Soul Food released?', '2019')],
#   'verdict_bool': None,
#   'verdict_raw': 'The question-evidence pairs partially confirm the claim. '
#                  'Tupac Shakur released the film Soul Food in 2019, but it was '
#                  'not Fox 2000 Pictures who released it.\n'
#                  '\n'
#                  'Inconclusive'},
#  {'claim': 'Anne Rice was born in New Jersey.',
#   'correct': False,
#   'qa_pairs': [('Who was born in New Jersey?',
#                 'Thomas Edison was born in New Jersey.'),
#                ('Was Anne Rice from New Jersey?',
#                 'No, Anne Rice was not from New Jersey. She was born in New '
#                 'Orleans, Louisiana.'),
#                ('Was Anne Rice born in New Jersey?',
#                 'No, Anne Rice was born in Louisiana.')],
#   'verdict_bool': False,
#   'verdict_raw': 'In a single, concise, logical sentence, addressing if the '
#                  'question-evidence pairs fully confirm or disprove the claim, '
#                  'the claim "Anne Rice was born in New Jersey" is confirmed by '
#                  'the evidence that Anne Rice was born in Louisiana. \n'
#                  '\n'
#                  'Conclusion: False'},
#  {'claim': 'Anne Rice was born in New Jersey.',
#   'correct': False,
#   'qa_pairs': [('Who was born in New Jersey?', 'Paul McCartney'),
#                ('When was Anne Rice born?',
#                 'Anne Rice was born on May 21, 1941.'),
#                ('What is the birthplace of Anne Rice?',
#                 'New Orleans, Louisiana')],
#   'verdict_bool': False,
#   'verdict_raw': 'False'},
#  {'claim': 'Telemundo is a English-language television network.',
#   'correct': True,
#   'qa_pairs': [('Is Telemundo considered an English-language television '
#                 'network?',
#                 'No, Telemundo is not considered an English-language '
#                 'television network. It is a Spanish-language television '
#                 'network based in Miami, Florida, United States.'),
#                ('Is Telemundo based in Miami, Florida, United States?', 'Yes.'),
#                ('Is Telemundo a Spanish-language television network or based '
#                 'in Miami, Florida, United States?',
#                 'Telemundo is a Spanish-language television network '
#                 'headquartered in Miami, Florida, United States.')],
#   'verdict_bool': False,
#   'verdict_raw': 'False\n'
#                  '\n'
#                  'Explanation: The question-evidence pairs do not fully '
#                  'confirm the claim that Telemundo is an English-language '
#                  'television network. Instead, they provide information about '
#                  "Telemundo's language and location, which contradicts the "
#                  'claim.'}]

# %%
tot_correct = 0
for result in results:
    if result["correct"]:
        tot_correct += 1
print(f'Accuracy: {tot_correct / len(results)}')
# Out:
# Accuracy: 0.1

# %%
# EXPORT-IGNORE-END
